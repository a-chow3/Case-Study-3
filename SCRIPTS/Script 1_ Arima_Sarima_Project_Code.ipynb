# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Crime Data.csv')
df.shape
# Out:
# (982638, 28)

# %%
df.tail()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 982633    20    Olympic         2033         1     341
# 982634     7   Wilshire          788         1     510
# 982635     1    Central          101         2     745
# 982636     3  Southwest          358         1     230
# 982637     9   Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Status  \
# 982633  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 982634                                   VEHICLE - STOLEN  ...     IC
# 982635           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 982636     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 982637                                   VEHICLE - STOLEN  ...     IC
#
#         Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 982633  Invest Cont    341.0      NaN       NaN      NaN
# 982634  Invest Cont    510.0      NaN       NaN      NaN
# 982635  Invest Cont    745.0      NaN       NaN      NaN
# 982636  Invest Cont    230.0      NaN       NaN      NaN
# 982637  Invest Cont    510.0      NaN       NaN      NaN
#
#                                        LOCATION  \
# 982633  3700    WILSHIRE                     BL
# 982634  4000 W  23RD                         ST
# 982635  1300 W  SUNSET                       BL
# 982636          FLOWER                       ST
# 982637  6900    VESPER                       AV
#
#                            Cross Street      LAT       LON
# 982633                              NaN  34.0617 -118.3066
# 982634                              NaN  34.0362 -118.3284
# 982635                              NaN  34.0685 -118.2460
# 982636  JEFFERSON                    BL  34.0215 -118.2868
# 982637                              NaN  34.1961 -118.4510
#
# [5 rows x 28 columns]

# %%
df = df.drop(columns = ["Cross Street", "Status", "AREA", "Crm Cd", "Part 1-2", "Premis Cd", "Crm Cd 4", "Crm Cd 3", "Weapon Used Cd"])

# %%
df['DATE OCC'] = df['DATE OCC'].str[:10]
df['Date Rptd'] = df['Date Rptd'].str[:10]
# df.tail()
# now we are going to convert to panda time series objects
df['DATE OCC'] = pd.to_datetime(
                            df['DATE OCC'],
                            format = '%m/%d/%Y')
df['Date Rptd'] = pd.to_datetime(
                            df['Date Rptd'],
                             format = '%m/%d/%Y')
df.tail()
# Out:
#             DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA NAME  Rpt Dist No  \
# 982633  242011172 2024-08-20 2024-08-17      2300    Olympic         2033
# 982634  240710284 2024-07-24 2024-07-23      1400   Wilshire          788
# 982635  240104953 2024-01-15 2024-01-15       100    Central          101
# 982636  240309674 2024-04-24 2024-04-24      1500  Southwest          358
# 982637  240910892 2024-08-13 2024-08-12      2300   Van Nuys          914
#
#                                               Crm Cd Desc  \
# 982633  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 982634                                   VEHICLE - STOLEN
# 982635           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 982636     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 982637                                   VEHICLE - STOLEN
#
#                               Mocodes  Vict Age Vict Sex Vict Descent  \
# 982633                      0344 1822        36        F            C
# 982634                            NaN         0      NaN          NaN
# 982635                 0329 0400 0416         0        X            X
# 982636  1822 0334 0416 0445 0449 1202        70        F            W
# 982637                            NaN         0      NaN          NaN
#
#                    Premis Desc                  Weapon Desc  Status Desc  \
# 982633  BAR/COCKTAIL/NIGHTCLUB                          NaN  Invest Cont
# 982634                  STREET                          NaN  Invest Cont
# 982635                   HOTEL  UNKNOWN WEAPON/OTHER WEAPON  Invest Cont
# 982636                SIDEWALK                        STICK  Invest Cont
# 982637             PARKING LOT                          NaN  Invest Cont
#
#         Crm Cd 1  Crm Cd 2                                 LOCATION      LAT  \
# 982633     341.0       NaN  3700    WILSHIRE                     BL  34.0617
# 982634     510.0       NaN  4000 W  23RD                         ST  34.0362
# 982635     745.0       NaN  1300 W  SUNSET                       BL  34.0685
# 982636     230.0       NaN          FLOWER                       ST  34.0215
# 982637     510.0       NaN  6900    VESPER                       AV  34.1961
#
#              LON
# 982633 -118.3066
# 982634 -118.3284
# 982635 -118.2460
# 982636 -118.2868
# 982637 -118.4510

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA NAME  Rpt Dist No  \
# 0  190326475 2020-03-01 2020-03-01      2130   Wilshire          784
# 1  200106753 2020-02-09 2020-02-08      1800    Central          182
# 2  200320258 2020-11-11 2020-11-04      1700  Southwest          356
# 3  200907217 2023-05-10 2020-03-10      2037   Van Nuys          964
# 4  220614831 2022-08-18 2020-08-17      1200  Hollywood          666
#
#                                 Crm Cd Desc              Mocodes  Vict Age  \
# 0                          VEHICLE - STOLEN                  NaN         0
# 1                     BURGLARY FROM VEHICLE       1822 1402 0344        47
# 2                             BIKE - STOLEN            0344 1251        19
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501        19
# 4                         THEFT OF IDENTITY  1822 1501 0930 2004        28
#
#   Vict Sex Vict Descent                                   Premis Desc  \
# 0        M            O                                        STREET
# 1        M            O             BUS STOP/LAYOVER (ALSO QUERY 124)
# 2        X            X  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3        M            O                                CLOTHING STORE
# 4        M            H                                      SIDEWALK
#
#   Weapon Desc   Status Desc  Crm Cd 1  Crm Cd 2  \
# 0         NaN  Adult Arrest     510.0     998.0
# 1         NaN   Invest Cont     330.0     998.0
# 2         NaN   Invest Cont     480.0       NaN
# 3         NaN   Invest Cont     343.0       NaN
# 4         NaN   Invest Cont     354.0       NaN
#
#                                    LOCATION      LAT       LON
# 0   1900 S  LONGWOOD                     AV  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST  34.0444 -118.2628
# 2   1400 W  37TH                         ST  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR  34.1576 -118.4387
# 4                         1900    TRANSIENT  34.0944 -118.3277

# %%
print(df['DATE OCC'].dtype)
print(df['Date Rptd'].dtype)
df['Year'] = df['DATE OCC'].dt.year
year_counts = df['Year'].value_counts()
print(year_counts)
# okay the previous code shows that it has been properly converted to a datetime object
# Out:
# datetime64[ns]
# datetime64[ns]
# Year
# 2022    235152
# 2023    232130
# 2021    209805
# 2020    199787
# 2024    105764
# Name: count, dtype: int64

# %%
  # Extract the year


df['Year'] = df['DATE OCC'].dt.year  # Extract the year

for year in df['Year'].unique():
    year_data = df[df['Year'] == year]  # Filter data for the current year
    year_data.groupby('DATE OCC')['DR_NO'].count().plot(kind='line', color ="darkblue")
    plt.title(f'Crime Occurrences in {year}')
    plt.xlabel('Date')
    plt.ylabel('Number of Crimes')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
df["YearMonth"] = df["DATE OCC"].dt.to_period("M")
df.head()
# counting the occurences of each crime type by each month
crime_counts = df.groupby(['YearMonth', 'Crm Cd Desc']).size().reset_index(name='Count')
crime_pivot = crime_counts.pivot(index='YearMonth', columns='Crm Cd Desc', values='Count')
crime_pivot.head()
crime_pivot.fillna(0, inplace=True) # some crimes didnt occur in a month so going to replace with the number zero instead
crime_pivot.index = crime_pivot.index.to_timestamp()
# going to calculate the top 20 crimes!
top_20_crimes = crime_pivot.sum().nlargest(20).index
crime_pivot = crime_pivot[top_20_crimes]
# making the plot now!
plt.figure(figsize=(12, 6))
sns.lineplot(data=crime_pivot)
plt.title('Monthly Crime Trends from 2020 to 2024 ')
plt.xlabel('Month')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.legend(title = 'Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
plt.tight_layout()
plt.show()

# %%
# going to make the same graph as previous but only going to do it in year 2020 because we are interested in covid's impact and protests
year_2020_data = df[df['Year'] == 2020]
year_2023_data = df[df['Year'] == 2023]
crime_counts = year_2020_data.groupby(['YearMonth', 'Crm Cd Desc']).size().reset_index(name='Count')
crime_pivot_2020 = crime_counts.pivot(index='YearMonth', columns='Crm Cd Desc', values='Count')
crime_pivot_2020.fillna(0, inplace=True)
crime_pivot_2020.index = crime_pivot_2020.index.to_timestamp()


# going to calculate the top 20 crimes!
top_20_crimes = crime_pivot_2020.sum().nlargest(20).index
crime_pivot_2020 = crime_pivot_2020[top_20_crimes]

# making the plot now!
plt.figure(figsize=(12, 6))
sns.lineplot(data=crime_pivot_2020)
plt.title('Monthly Crime Trends in 2020')
plt.xlabel('Month')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.legend(title = 'Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
plt.tight_layout()
plt.show()

# %%
# going to compare to 2023; a more "normal" year
crime_counts_2023 = year_2023_data.groupby(['YearMonth', 'Crm Cd Desc']).size().reset_index(name='Count')
crime_pivot_2023 = crime_counts_2023.pivot(index='YearMonth', columns='Crm Cd Desc', values='Count')
crime_pivot_2023.fillna(0, inplace=True)
crime_pivot_2023.index = crime_pivot_2023.index.to_timestamp()


# going to calculate the top 20 crimes!
top_20_crimes_2023 = crime_pivot_2023.sum().nlargest(20).index
crime_pivot_2023 = crime_pivot_2023[top_20_crimes_2023]

# making the plot now!
plt.figure(figsize=(12, 6))
sns.lineplot(data=crime_pivot_2023)
plt.title('Monthly Crime Trends in 2023')
plt.xlabel('Month')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.legend(title = 'Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA NAME  Rpt Dist No  \
# 0  190326475 2020-03-01 2020-03-01      2130   Wilshire          784
# 1  200106753 2020-02-09 2020-02-08      1800    Central          182
# 2  200320258 2020-11-11 2020-11-04      1700  Southwest          356
# 3  200907217 2023-05-10 2020-03-10      2037   Van Nuys          964
# 4  220614831 2022-08-18 2020-08-17      1200  Hollywood          666
#
#                                 Crm Cd Desc              Mocodes  Vict Age  \
# 0                          VEHICLE - STOLEN                  NaN         0
# 1                     BURGLARY FROM VEHICLE       1822 1402 0344        47
# 2                             BIKE - STOLEN            0344 1251        19
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501        19
# 4                         THEFT OF IDENTITY  1822 1501 0930 2004        28
#
#   Vict Sex  ...                                   Premis Desc Weapon Desc  \
# 0        M  ...                                        STREET         NaN
# 1        M  ...             BUS STOP/LAYOVER (ALSO QUERY 124)         NaN
# 2        X  ...  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)         NaN
# 3        M  ...                                CLOTHING STORE         NaN
# 4        M  ...                                      SIDEWALK         NaN
#
#     Status Desc Crm Cd 1  Crm Cd 2                                  LOCATION  \
# 0  Adult Arrest    510.0     998.0   1900 S  LONGWOOD                     AV
# 1   Invest Cont    330.0     998.0   1000 S  FLOWER                       ST
# 2   Invest Cont    480.0       NaN   1400 W  37TH                         ST
# 3   Invest Cont    343.0       NaN  14000    RIVERSIDE                    DR
# 4   Invest Cont    354.0       NaN                         1900    TRANSIENT
#
#        LAT       LON  Year  YearMonth
# 0  34.0375 -118.3506  2020    2020-03
# 1  34.0444 -118.2628  2020    2020-02
# 2  34.0210 -118.3002  2020    2020-11
# 3  34.1576 -118.4387  2020    2020-03
# 4  34.0944 -118.3277  2020    2020-08
#
# [5 rows x 21 columns]

# %%
# going to look at the weapons utilized
weapon_counts = df['Weapon Desc'].value_counts()
pd.set_option("display.max_rows", None)
print(weapon_counts)
top_30_weapons = weapon_counts.head(30)
# going to make a bar chart of weapons
plt.figure(figsize=(10, 6))
top_30_weapons.plot(kind='bar')
plt.title('Distribution of Weapons Used')
plt.xlabel('Weapon Description')
plt.ylabel('Number of Occurrences')
# group rifles, stabby things, firearms,
# Out:
# Weapon Desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    174413
# UNKNOWN WEAPON/OTHER WEAPON                        35945
# VERBAL THREAT                                      23802
# HAND GUN                                           20107
# SEMI-AUTOMATIC PISTOL                               7246
# KNIFE WITH BLADE 6INCHES OR LESS                    6824
# UNKNOWN FIREARM                                     6568
# OTHER KNIFE                                         5874
# MACE/PEPPER SPRAY                                   3728
# VEHICLE                                             3243
# ROCK/THROWN OBJECT                                  2731
# PIPE/METAL PIPE                                     2464
# BOTTLE                                              2412
# FOLDING KNIFE                                       2260
# STICK                                               2246
# CLUB/BAT                                            2087
# KITCHEN KNIFE                                       1918
# AIR PISTOL/REVOLVER/RIFLE/BB GUN                    1856
# KNIFE WITH BLADE OVER 6 INCHES IN LENGTH            1697
# BLUNT INSTRUMENT                                    1385
# HAMMER                                              1352
# SIMULATED GUN                                       1248
# REVOLVER                                            1179
# MACHETE                                             1143
# OTHER FIREARM                                        944
# PHYSICAL PRESENCE                                    930
# OTHER CUTTING INSTRUMENT                             929
# UNKNOWN TYPE CUTTING INSTRUMENT                      878
# SCREWDRIVER                                          782
# CONCRETE BLOCK/BRICK                                 705
# BELT FLAILING INSTRUMENT/CHAIN                       688
# FIRE                                                 680
# SCISSORS                                             658
# RIFLE                                                495
# FIXED OBJECT                                         406
# STUN GUN                                             395
# GLASS                                                335
# AXE                                                  323
# SHOTGUN                                              314
# BOARD                                                310
# CAUSTIC CHEMICAL/POISON                              240
# SWITCH BLADE                                         233
# BRASS KNUCKLES                                       207
# BOMB THREAT                                          194
# TOY GUN                                              157
# TIRE IRON                                            149
# SCALDING LIQUID                                      145
# SWORD                                                138
# RAZOR BLADE                                          118
# HECKLER & KOCH 93 SEMIAUTOMATIC ASSAULT RIFLE        102
# DIRK/DAGGER                                           92
# EXPLOXIVE DEVICE                                      86
# ASSAULT WEAPON/UZI/AK47/ETC                           77
# ICE PICK                                              69
# DEMAND NOTE                                           65
# RAZOR                                                 65
# SEMI-AUTOMATIC RIFLE                                  55
# LIQUOR/DRUGS                                          54
# DOG/ANIMAL (SIC ANIMAL ON)                            53
# ROPE/LIGATURE                                         50
# STARTER PISTOL/REVOLVER                               41
# CLEAVER                                               36
# BOWIE KNIFE                                           33
# BOW AND ARROW                                         28
# AUTOMATIC WEAPON/SUB-MACHINE GUN                      28
# SAWED OFF RIFLE/SHOTGUN                               28
# SYRINGE                                               22
# STRAIGHT RAZOR                                        19
# UNK TYPE SEMIAUTOMATIC ASSAULT RIFLE                  15
# MARTIAL ARTS WEAPONS                                  14
# RELIC FIREARM                                         13
# BLACKJACK                                             12
# UZI SEMIAUTOMATIC ASSAULT RIFLE                       10
# ANTIQUE FIREARM                                        9
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    3
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          2
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    2
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       2
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       1
# Name: count, dtype: int64
# Text(0, 0.5, 'Number of Occurrences')

# %%
# lets begin looking at the ARIMA/SARIMA model
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
# !pip install pmdarima
from pmdarima.arima import auto_arima
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.10/dist-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
# creating a subset of the data that groups the number of crimes by each month
crimes_per_month= df.groupby(['YearMonth']).size().reset_index(name='Count')
crimes_per_month.head()
# grouped by date (separated into month day and year; treated as three separate columns) and only used specific columns
# okay going to group a different way to see if that impacts MSE and RMSE
# first going to create three separate columns for each component of the date; Month, Day and Year
# df_grouped = df.groupby([df['DATE OCC'].dt.to_period('M'), 'AREA NAME', "Crm Cd Desc", "Vict Sex", "Vict Descent", "Premis Desc", "Weapon Desc", "Status Desc"]).size().reset_index(name='crime_count')
# df_grouped['Month'] = df_grouped['DATE OCC'].dt.month
# df_grouped['Day'] = df_grouped['DATE OCC'].dt.day
# df_grouped['Year'] = df_grouped['DATE OCC'].dt.year
# df_grouped.head()
# Out:
#   YearMonth  Count
# 0   2020-01  18560
# 1   2020-02  17278
# 2   2020-03  16187
# 3   2020-04  15701
# 4   2020-05  17228

# %%
# starting with parameter analysis
# link for all the following code: https://www.geeksforgeeks.org/python-arima-model-for-time-series-forecasting/
stepwise_fit = auto_arima(crimes_per_month['Count'], start_p=1, start_q=1,
                          max_p=3, max_q=3, m=12,
                          start_P=0, seasonal=True,
                          d= None, D=0, trace=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1087.927, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1037.511, Time=0.72 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1277.824, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=1035.661, Time=0.41 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=1054.819, Time=0.98 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=1039.402, Time=1.88 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=1005.311, Time=0.81 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=990.707, Time=1.37 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=982.509, Time=6.23 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=7.80 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=2.30 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=5.57 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=991.463, Time=2.20 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=963.534, Time=0.74 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=961.652, Time=0.45 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=979.414, Time=0.17 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=959.570, Time=0.51 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=960.378, Time=0.58 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(1,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=1.46 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=1010.086, Time=1.80 sec
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=958.700, Time=2.37 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=956.958, Time=0.36 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=964.253, Time=0.06 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=957.972, Time=0.73 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=957.748, Time=0.45 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=959.984, Time=1.09 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=958.984, Time=0.53 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=958.759, Time=0.28 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=958.510, Time=0.40 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=960.304, Time=0.53 sec
#  ARIMA(2,0,2)(0,0,1)[12]             : AIC=958.839, Time=0.34 sec
#
# Best model:  ARIMA(2,0,2)(0,0,1)[12] intercept
# Total fit time: 48.314 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   57
# Model:             SARIMAX(2, 0, 2)x(0, 0, [1], 12)   Log Likelihood                -471.479
# Date:                              Thu, 24 Oct 2024   AIC                            956.958
# Time:                                      17:08:50   BIC                            971.260
# Sample:                                           0   HQIC                           962.516
#                                                - 57
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    888.5201    512.213      1.735      0.083    -115.398    1892.439
# ar.L1          1.8698      0.186     10.066      0.000       1.506       2.234
# ar.L2         -0.9222      0.189     -4.874      0.000      -1.293      -0.551
# ma.L1         -0.7190      0.243     -2.964      0.003      -1.194      -0.244
# ma.L2          0.1452      0.218      0.666      0.505      -0.282       0.572
# ma.S.L12       0.5200      0.206      2.526      0.012       0.117       0.924
# sigma2      7.977e+05      0.137   5.83e+06      0.000    7.98e+05    7.98e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.77
# Prob(Q):                              1.00   Prob(JB):                         0.25
# Heteroskedasticity (H):               1.64   Skew:                            -0.13
# Prob(H) (two-sided):                  0.29   Kurtosis:                         4.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.01e+22. Standard errors may be unstable.
# """

# %%
# splitting the data into train/test sets
training = crimes_per_month[:int(0.8*len(crimes_per_month))] # utilizing 80% of the data
testing = crimes_per_month[int(0.8*len(crimes_per_month)):] # utilizing 20% of the data
# fitting sarimax
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(training['Count'], order=(1, 1, 1), seasonal_order=(2, 1, 1, 12))
result = model.fit()
result.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Count   No. Observations:                   45
# Model:             SARIMAX(1, 1, 1)x(2, 1, 1, 12)   Log Likelihood                -259.796
# Date:                            Thu, 24 Oct 2024   AIC                            531.592
# Time:                                    17:08:51   BIC                            540.386
# Sample:                                         0   HQIC                           534.507
#                                              - 45
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4251      1.787     -0.238      0.812      -3.928       3.078
# ma.L1          0.4933      1.599      0.308      0.758      -2.641       3.627
# ar.S.L12      -1.1078      2.767     -0.400      0.689      -6.532       4.316
# ar.S.L24      -0.1315      0.474     -0.278      0.781      -1.060       0.797
# ma.S.L12       0.9548      3.094      0.309      0.758      -5.109       7.019
# sigma2      6.388e+05   8.93e-05   7.16e+09      0.000    6.39e+05    6.39e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 1.15
# Prob(Q):                              0.85   Prob(JB):                         0.56
# Heteroskedasticity (H):               0.94   Skew:                             0.41
# Prob(H) (two-sided):                  0.92   Kurtosis:                         2.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.89e+25. Standard errors may be unstable.
# """

# %%
# predictions of arima model vs test
start = len(training)
end = len(training) + len(testing) - 1
predictions = result.predict(start=start, end=end, typ='levels').rename('Predictions')
#plotting predictions vs actual
predictions.plot(legend=True)
# going to change the x and y axis title name
plt.xlabel('Date')
plt.ylabel('Number of Occurrences')
# going to change
testing['Count'].plot(legend=True)
# okay yay this works but i should try debugging the code so the graphs are more interpretable
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='Date', ylabel='Number of Occurrences'>

# %%
# going to evaluate the model
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
# calculating the root mean squared error
rmse(testing['Count'], predictions)
# Out:
# 7823.191185185013

# %%
# calculating mean squared error
mean_squared_error(testing['Count'], predictions)
# Out:
# 61202320.31995648

# %%
# starting with the SARIMA
# link to references: https://www.geeksforgeeks.org/sarima-seasonal-autoregressive-integrated-moving-average/
# first starting by plotting the monthly crimes
plt.figure(figsize=(12,6))
plt.plot(crimes_per_month['Count'])
plt.title('Monthly Crime Trends')
plt.xlabel('Month')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45)
# might have to go back convert to dataframe a different way because why is it registering the months as simple numbers ...
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
# Define SARIMA parameters
p, d, q = 1, 1, 1
P, D, Q, s = 1, 1, 1, 12  # Assuming monthly seasonality

# Fit the SARIMA model
model = SARIMAX(crimes_per_month['Count'], order=(p, d, q), seasonal_order=(P, D, Q, s))
results = model.fit()
print(results.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Count   No. Observations:                   57
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -367.402
# Date:                            Thu, 24 Oct 2024   AIC                            744.803
# Time:                                    17:08:55   BIC                            753.724
# Sample:                                         0   HQIC                           748.112
#                                              - 57
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1019      0.282      0.362      0.717      -0.450       0.654
# ma.L1          0.1607      0.279      0.576      0.564      -0.386       0.707
# ar.S.L12      -0.3759      0.907     -0.414      0.679      -2.154       1.402
# ma.S.L12       0.2624      0.968      0.271      0.786      -1.635       2.160
# sigma2      9.148e+05    1.8e+05      5.090      0.000    5.63e+05    1.27e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.74   Jarque-Bera (JB):                 1.25
# Prob(Q):                              0.10   Prob(JB):                         0.54
# Heteroskedasticity (H):               1.74   Skew:                            -0.27
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast future values
forecast_periods = 12  # Forecast the next 12 months
forecast = results.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_ci = forecast.conf_int()

# Plot the forecast
plt.figure(figsize=(12, 6))
# Access the column using 'Count' instead of 'count'
plt.plot(crimes_per_month['Count'], label='Observed')
plt.plot(forecast_mean, label='Forecast', color='red')
plt.fill_between(forecast_ci.index, forecast_ci.iloc[:, 0], forecast_ci.iloc[:, 1], color='pink')
plt.title("Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Number of Occurrences")
plt.legend()
plt.show()

# %%
# going to calculate the mse and rmse
mse = mean_squared_error(testing['Count'], predictions)
rmse = np.sqrt(mse)
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Squared Error (MSE): 61202320.31995648
# Root Mean Squared Error (RMSE): 7823.191185185013

# %%
# going to examine the most popular crimes in which the age column == 0
df_age_zero = df[df['Vict Age'] == 0]
# now going to do the number of crime occurences
crime_counts_zero = df_age_zero['Crm Cd Desc'].value_counts()
pd.set_option("display.max_rows", None)

print(crime_counts)
# Out:
#      YearMonth                                        Crm Cd Desc  Count
# 0      2020-01                                              ARSON     45
# 1      2020-01       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER      1
# 2      2020-01     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    810
# 3      2020-01                                  ATTEMPTED ROBBERY    105
# 4      2020-01                           BATTERY - SIMPLE ASSAULT   1534
# 5      2020-01                           BATTERY ON A FIREFIGHTER      1
# 6      2020-01                            BATTERY POLICE (SIMPLE)     57
# 7      2020-01                        BATTERY WITH SEXUAL CONTACT    122
# 8      2020-01                                      BIKE - STOLEN    156
# 9      2020-01                                      BOAT - STOLEN      4
# 10     2020-01                                         BOMB SCARE     16
# 11     2020-01                                    BRANDISH WEAPON    235
# 12     2020-01                                            BRIBERY      1
# 13     2020-01                                     BUNCO, ATTEMPT      6
# 14     2020-01                                 BUNCO, GRAND THEFT    159
# 15     2020-01                                 BUNCO, PETTY THEFT     91
# 16     2020-01                                           BURGLARY    982
# 17     2020-01                              BURGLARY FROM VEHICLE   1444
# 18     2020-01                   BURGLARY FROM VEHICLE, ATTEMPTED     12
# 19     2020-01                                BURGLARY, ATTEMPTED     88
# 20     2020-01                                  CHILD ABANDONMENT      2
# 21     2020-01        CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT     15
# 22     2020-01            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT     99
# 23     2020-01                     CHILD ANNOYING (17YRS & UNDER)     37
# 24     2020-01                     CHILD NEGLECT (SEE 300 W.I.C.)     24
# 25     2020-01                                  CHILD PORNOGRAPHY      4
# 26     2020-01                                     CHILD STEALING      6
# 27     2020-01                                         CONSPIRACY      2
# 28     2020-01                                  CONTEMPT OF COURT     41
# 29     2020-01                                       CONTRIBUTING      1
# 30     2020-01                                        COUNTERFEIT      5
# 31     2020-01              CREDIT CARDS, FRAUD USE ($950 & UNDER      3
# 32     2020-01           CREDIT CARDS, FRAUD USE ($950.01 & OVER)      1
# 33     2020-01                                  CRIMINAL HOMICIDE     29
# 34     2020-01             CRIMINAL THREATS - NO WEAPON DISPLAYED    410
# 35     2020-01  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...    103
# 36     2020-01  DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 &...     12
# 37     2020-01  DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $...      4
# 38     2020-01                     DISCHARGE FIREARMS/SHOTS FIRED     46
# 39     2020-01                   DISHONEST EMPLOYEE - GRAND THEFT      1
# 40     2020-01                                     DISRUPT SCHOOL      2
# 41     2020-01                               DISTURBING THE PEACE     25
# 42     2020-01                   DOCUMENT FORGERY / STOLEN FELONY    108
# 43     2020-01                DOCUMENT WORTHLESS ($200.01 & OVER)      1
# 44     2020-01               DRIVING WITHOUT OWNER CONSENT (DWOC)      4
# 45     2020-01                                  DRUGS, TO A MINOR      1
# 46     2020-01                                         DRUNK ROLL      1
# 47     2020-01         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT      1
# 410    2020-04  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...     10
# 411    2020-04                                           STALKING     13
# 412    2020-04                 THEFT FROM MOTOR VEHICLE - ATTEMPT     24
# 413    2020-04  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...    330
# 414    2020-04    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)    869
# 415    2020-04                        THEFT FROM PERSON - ATTEMPT      1
# 416    2020-04                                  THEFT OF IDENTITY    681
# 417    2020-04                              THEFT PLAIN - ATTEMPT     10
# 418    2020-04                 THEFT PLAIN - PETTY ($950 & UNDER)    779
# 419    2020-04                                      THEFT, PERSON     50
# 420    2020-04  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...    366
# 421    2020-04                    THREATENING PHONE CALLS/LETTERS      8
# 422    2020-04                  THROWING OBJECT AT MOVING VEHICLE     10
# 423    2020-04                                        TRESPASSING    220
# 424    2020-04                       UNAUTHORIZED COMPUTER ACCESS     14
# 425    2020-04  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...   1009
# 426    2020-04           VANDALISM - MISDEAMEANOR ($399 OR UNDER)    560
# 427    2020-04                           VEHICLE - ATTEMPT STOLEN     49
# 428    2020-04                                   VEHICLE - STOLEN   1838
# 429    2020-04  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...     12
# 430    2020-04                           VIOLATION OF COURT ORDER    114
# 431    2020-04                     VIOLATION OF RESTRAINING ORDER    237
# 432    2020-04           VIOLATION OF TEMPORARY RESTRAINING ORDER     12
# 433    2020-04                         WEAPONS POSSESSION/BOMBING      2
# 434    2020-05                                              ARSON     71
# 435    2020-05       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER    150
# 436    2020-05     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    966
# 437    2020-05                                  ATTEMPTED ROBBERY     78
# 438    2020-05                           BATTERY - SIMPLE ASSAULT   1330
# 439    2020-05                           BATTERY ON A FIREFIGHTER      5
# 440    2020-05                            BATTERY POLICE (SIMPLE)     62
# 441    2020-05                        BATTERY WITH SEXUAL CONTACT     60
# 442    2020-05                            BIKE - ATTEMPTED STOLEN      1
# 443    2020-05                                      BIKE - STOLEN    198
# 444    2020-05                                      BOAT - STOLEN      3
# 445    2020-05                                         BOMB SCARE      4
# 446    2020-05                                    BRANDISH WEAPON    277
# 447    2020-05                                     BUNCO, ATTEMPT      4
# 448    2020-05                                 BUNCO, GRAND THEFT     68
# 449    2020-05                                 BUNCO, PETTY THEFT     46
# 450    2020-05                                           BURGLARY   1443
# 451    2020-05                              BURGLARY FROM VEHICLE   1049
# 452    2020-05                   BURGLARY FROM VEHICLE, ATTEMPTED     22
# 453    2020-05                                BURGLARY, ATTEMPTED     90
# 454    2020-05        CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT     13
# 455    2020-05            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT     58
# 456    2020-05                     CHILD ANNOYING (17YRS & UNDER)     22
# 457    2020-05                     CHILD NEGLECT (SEE 300 W.I.C.)     19
# 458    2020-05                                  CHILD PORNOGRAPHY      8
# 459    2020-05                                     CHILD STEALING     10
# 460    2020-05                                  CONTEMPT OF COURT     50
# 461    2020-05                                       CONTRIBUTING      1
# 462    2020-05                                        COUNTERFEIT      5
# 463    2020-05              CREDIT CARDS, FRAUD USE ($950 & UNDER      3
# 464    2020-05           CREDIT CARDS, FRAUD USE ($950.01 & OVER)      4
# 465    2020-05                                  CRIMINAL HOMICIDE     21
# 466    2020-05             CRIMINAL THREATS - NO WEAPON DISPLAYED    330
# 467    2020-05  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...     17
# 468    2020-05                                 CRUELTY TO ANIMALS      2
# 469    2020-05  DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 &...
ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT   1072
# 650    2020-07                                  ATTEMPTED ROBBERY    100
# 651    2020-07                           BATTERY - SIMPLE ASSAULT   1472
# 652    2020-07                           BATTERY ON A FIREFIGHTER      7
# 653    2020-07                            BATTERY POLICE (SIMPLE)     65
# 654    2020-07                        BATTERY WITH SEXUAL CONTACT     71
# 655    2020-07                                      BIKE - STOLEN    168
# ...
# 1068   2020-10                           VEHICLE - ATTEMPT STOLEN     43
# 1069   2020-10                                   VEHICLE - STOLEN   1818
# 1070   2020-10  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...     15
# 1071   2020-10                           VIOLATION OF COURT ORDER    134
# 1072   2020-10                     VIOLATION OF RESTRAINING ORDER    211
# 1073   2020-10           VIOLATION OF TEMPORARY RESTRAINING ORDER     10
# 1074   2020-10                         WEAPONS POSSESSION/BOMBING      1
# 1075   2020-11                                              ARSON     55
# 1076   2020-11       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER     12
# 1077   2020-11     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    971
# 1078   2020-11                                  ATTEMPTED ROBBERY     92
# 1079   2020-11                           BATTERY - SIMPLE ASSAULT   1244
# 1080   2020-11                           BATTERY ON A FIREFIGHTER      6
# 1081   2020-11                            BATTERY POLICE (SIMPLE)     32
# 1082   2020-11                        BATTERY WITH SEXUAL CONTACT     76
# 1083   2020-11                                      BIKE - STOLEN    151
# 1084   2020-11                                      BOAT - STOLEN      1
# 1085   2020-11                                         BOMB SCARE      4
# 1086   2020-11                                    BRANDISH WEAPON    265
# 1087   2020-11                                     BUNCO, ATTEMPT      5
# 1088   2020-11                                 BUNCO, GRAND THEFT     87
# 1089   2020-11                                 BUNCO, PETTY THEFT     37
# 1090   2020-11                                           BURGLARY   1043
# 1091   2020-11                              BURGLARY FROM VEHICLE    979
# 1092   2020-11                   BURGLARY FROM VEHICLE, ATTEMPTED     17
# 1093   2020-11                                BURGLARY, ATTEMPTED     78
# 1094   2020-11        CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT      9
# 1095   2020-11            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT     63
# 1096   2020-11                     CHILD ANNOYING (17YRS & UNDER)     19
# 1097   2020-11                     CHILD NEGLECT (SEE 300 W.I.C.)     21
# 1098   2020-11                                  CHILD PORNOGRAPHY      2
# 1099   2020-11                                     CHILD STEALING      9
# 1100   2020-11                                  CONTEMPT OF COURT     58
# 1101   2020-11                                       CONTRIBUTING      1
# 1102   2020-11                                        COUNTERFEIT      3
# 1103   2020-11           CREDIT CARDS, FRAUD USE ($950.01 & OVER)      2
# 1104   2020-11                                  CRIMINAL HOMICIDE     27
# 1105   2020-11             CRIMINAL THREATS - NO WEAPON DISPLAYED    294
# 1106   2020-11  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...     20
# 1107   2020-11                                 CRUELTY TO ANIMALS      3
# 1108   2020-11  DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 &...      5
# 1109   2020-11                     DISCHARGE FIREARMS/SHOTS FIRED     56
# 1110   2020-11                   DISHONEST EMPLOYEE - GRAND THEFT      1
# 1111   2020-11                   DISHONEST EMPLOYEE - PETTY THEFT      1
# 1112   2020-11                               DISTURBING THE PEACE     31
# 1113   2020-11                   DOCUMENT FORGERY / STOLEN FELONY     40
# 1114   2020-11                  DOCUMENT WORTHLESS ($200 & UNDER)      1
# 1115   2020-11               DRIVING WITHOUT OWNER CONSENT (DWOC)      4
# 1116   2020-11                                         DRUNK ROLL      1
# 1117   2020-11         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...      5
# 1177   2020-11                           VIOLATION OF COURT ORDER    105
# 1178   2020-11                     VIOLATION OF RESTRAINING ORDER    220
# 1179   2020-11           VIOLATION OF TEMPORARY RESTRAINING ORDER      8
# 1180   2020-11                         WEAPONS POSSESSION/BOMBING      1
# 1181   2020-12                                              ARSON     49
# 1182   2020-12       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER     15
# 1183   2020-12     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    959
# 1184   2020-12                                  ATTEMPTED ROBBERY     88
# 1185   2020-12                           BATTERY - SIMPLE ASSAULT   1186
# 1186   2020-12                           BATTERY ON A FIREFIGHTER      3
# 1187   2020-12                            BATTERY POLICE (SIMPLE)     35
# 1188   2020-12                        BATTERY WITH SEXUAL CONTACT     55
# 1189   2020-12                                      BIKE - STOLEN    146
# 1190   2020-12                                      BOAT - STOLEN      2
# 1191   2020-12                                         BOMB SCARE      4
# 1192   2020-12                                    BRANDISH WEAPON    244
# 1193   2020-12                                     BUNCO, ATTEMPT      6
# 1194   2020-12                                 BUNCO, GRAND THEFT     74
# 1195   2020-12                                 BUNCO, PETTY THEFT     25
# 1196   2020-12                                           BURGLARY   1093
# 1197   2020-12                              BURGLARY FROM VEHICLE   1023
# 1198   2020-12                   BURGLARY FROM VEHICLE, ATTEMPTED     13
# 1199   2020-12                                BURGLARY, ATTEMPTED     82
# 1200   2020-12        CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT      7
# 1201   2020-12            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT     38
# 1202   2020-12                     CHILD ANNOYING (17YRS & UNDER)      9
# 1203   2020-12                     CHILD NEGLECT (SEE 300 W.I.C.)     17
# 1204   2020-12                                  CHILD PORNOGRAPHY      1
# 1205   2020-12                                     CHILD STEALING      8
# 1206   2020-12                                  CONTEMPT OF COURT     53
# 1207   2020-12                                       CONTRIBUTING      3
# 1208   2020-12                                        COUNTERFEIT      2
# 1209   2020-12           CREDIT CARDS, FRAUD USE ($950.01 & OVER)      1
# 1210   2020-12                                  CRIMINAL HOMICIDE     40
# 1211   2020-12             CRIMINAL THREATS - NO WEAPON DISPLAYED    296
# 1212   2020-12  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...     26
# 1213   2020-12                                 CRUELTY TO ANIMALS      2
# 1214   2020-12  DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 &...      3
# 1215   2020-12                     DISCHARGE FIREARMS/SHOTS FIRED     61
# 1216   2020-12                   DISHONEST EMPLOYEE - GRAND THEFT      1
# 1217   2020-12                   DISHONEST EMPLOYEE - PETTY THEFT      1
# 1218   2020-12                               DISTURBING THE PEACE     17
# 1219   2020-12                   DOCUMENT FORGERY / STOLEN FELONY     54
# 1220   2020-12                  DOCUMENT WORTHLESS ($200 & UNDER)      1
# 1221   2020-12                DOCUMENT WORTHLESS ($200.01 & OVER)      2
# 1222   2020-12               DRIVING WITHOUT OWNER CONSENT (DWOC)      5
# 1223   2020-12         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)     66
# 1224   2020-12           EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)      1
# 1225   2020-12                                          EXTORTION     30
# 1226   2020-12                                   FAILURE TO YIELD     22
# 1227   2020-12                                 FALSE IMPRISONMENT      3
# 1228   2020-12                                FALSE POLICE REPORT      3
# 1229   2020-12            HUMAN TRAFFICKING - COMMERCIAL SEX ACTS      6
# 1230   2020-12          HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE      4
# 1231   2020-12                                    ILLEGAL DUMPING      3
# 1232   2020-12                                  INDECENT EXPOSURE      8
# 1233   2020-12              INTIMATE PARTNER - AGGRAVATED ASSAULT    214
# 1234   2020-12                  INTIMATE PARTNER - SIMPLE ASSAULT    821
# 1235   2020-12                                         KIDNAPPING     10
# 1236   2020-12                         KIDNAPPING - GRAND ATTEMPT      3
# 1237   2020-12            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD    123
# 1238   2020-12                                       LEWD CONDUCT      6
# 1239   2020-12                    LEWD/LASCIVIOUS ACTS WITH CHILD      2
# 1240   2020-12                                           LYNCHING      1
# 1241   2020-12                                    ORAL COPULATION      8
# 1242   2020-12                                      OTHER ASSAULT     69
# 1243   2020-12                          OTHER MISCELLANEOUS CRIME    128
# 1244   2020-12                                        PEEPING TOM     10
# 1245   2020-12                                         PICKPOCKET      5
# 1246   2020-12                                            PIMPING      4
# 1247   2020-12                                            PROWLER      5
# 1248   2020-12                                    PURSE SNATCHING      7
# 1249   2020-12                                    RAPE, ATTEMPTED      4
# 1250   2020-12                                     RAPE, FORCIBLE     59
# 1251   2020-12                                   RECKLESS DRIVING      6
# 1252   2020-12                                   RESISTING ARREST     25
# 1253   2020-12                                            ROBBERY    594
# 1254   2020-12          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE     14
# 1255   2020-12  SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W...     18
# 1256   2020-12                SEXUAL PENETRATION W/FOREIGN OBJECT     22
# 1257   2020-12                              SHOPLIFTING - ATTEMPT      1
# 1258   2020-12           SHOPLIFTING - PETTY THEFT ($950 & UNDER)    286
# 1259   2020-12           SHOPLIFTING-GRAND THEFT ($950.01 & OVER)     48
# 1260   2020-12                  SHOTS FIRED AT INHABITED DWELLING     50
# 1261   2020-12   SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT     11
# 1262   2020-12  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...      7
# 1263   2020-12                                           STALKING      8
# 1264   2020-12                 THEFT FROM MOTOR VEHICLE - ATTEMPT     25
# 1265   2020-12  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...    530
# 1266   2020-12    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)    754
# 1267   2020-12                        THEFT FROM PERSON - ATTEMPT      3
# 1268   2020-12                                  THEFT OF IDENTITY    742
# 1269   2020-12                              THEFT PLAIN - ATTEMPT      9
# 1270   2020-12                 THEFT PLAIN - PETTY ($950 & UNDER)   1008
# 1271   2020-12       THEFT, COIN MACHINE - GRAND ($950.01 & OVER)      1
# 1272   2020-12         THEFT, COIN MACHINE - PETTY ($950 & UNDER)      1
# 1273   2020-12                                      THEFT, PERSON     65
# 1274   2020-12  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...    465
# 1275   2020-12                    THREATENING PHONE CALLS/LETTERS      7
# 1276   2020-12                  THROWING OBJECT AT MOVING VEHICLE     12
# 1277   2020-12                                        TRESPASSING    205
# 1278   2020-12                       UNAUTHORIZED COMPUTER ACCESS      3
# 1279   2020-12  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...    985
# 1280   2020-12           VANDALISM - MISDEAMEANOR ($399 OR UNDER)    547
# 1281   2020-12                           VEHICLE - ATTEMPT STOLEN     50
# 1282   2020-12                                   VEHICLE - STOLEN   1804
# 1283   2020-12  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...     14
# 1284   2020-12                           VIOLATION OF COURT ORDER     88
# 1285   2020-12                     VIOLATION OF RESTRAINING ORDER    182
# 1286   2020-12           VIOLATION OF TEMPORARY RESTRAINING ORDER     11
